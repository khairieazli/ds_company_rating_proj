# %%
import pandas as pd

# %%
df = pd.read_csv('glassdoor_jobs.csv')

# %%
#Company name text only
#Industry field
#Parsing of job description

# %%
df.head()
# Out:
#                                            Job Title  Salary Estimate  \
# 0                              Junior Data Scientist               -1
# 1  Associate - Data & Analytics, Technology Consu...               -1
# 2                          Scientist 1, Data Science               -1
# 3                           Data Scientist Executive               -1
# 4                           Data Scientist Executive               -1
#
#                                      Job Description  Rating  \
# 0  ABOUT YOURSELF\nYou are a data-driven problem ...     2.9
# 1  EY DnA is the\ndata and advanced analytics cap...     3.8
# 2  SCIENTIST 1, DATA SCIENCE\n\nPetaling Jaya, Se...     3.5
# 3  *Location: Petaling Jaya*\nResponsibilities *\...    -1.0
# 4  *Location: Petaling Jaya*\nResponsibilities *\...    -1.0
#
#                   Company Name       Location  Headquarters  \
# 0      Juris Technologies\n2.9   Kuala Lumpur            -1
# ...

# %%
company = df['Company Name'].apply(lambda x: x.split('\n')[0])

# %%
company
# Out:
# 0                            Juris Technologies
# 1                                            EY
# 2                               Western Digital
# 3                               Western Digital
# 4                   Idealseed Resources Sdn Bhd
#                          ...
# 995                                       Roche
# 996                        Public Mutual Berhad
# 997                                     Cargill
# 998    Spring Professional (Malaysia) Sdn. Bhd.
# 999                                         ADA
# Name: Company Name, Length: 1000, dtype: object

# %%
df
# Out:
#                                              Job Title  Salary Estimate  \
# 0                                Junior Data Scientist               -1
# 1    Associate - Data & Analytics, Technology Consu...               -1
# 2                            Scientist 1, Data Science               -1
# 3                             Data Scientist Executive               -1
# 4                             Data Scientist Executive               -1
# ..                                                 ...              ...
# 995                                       Data Analyst               -1
# 996                                      Data Engineer               -1
# 997                                      Data Engineer               -1
# 998                                  Data Analyst Lead               -1
# 999                                      Data Engineer               -1
#
#                                        Job Description  Rating  \
# ...
